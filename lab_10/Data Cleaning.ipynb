# %%
import pandas as pd
import numpy as np

# %%
alameda = pd.read_csv("alamedatwitter_11_5.csv")

# %%
len(alameda)
# Out:
# 6994566

# %%
alameda_sample = alameda.sample(int((1/8)*len(alameda)))

# %%
len(alameda_sample)
# Out:
# 874320

# %%
alameda_sample.head()
# Out:
#          Unnamed: 0             id           u_id        lat         lon  \
# 4028036    27690560  4.535225e-278  1.112537e-308  37.751440 -122.201470
# 3632268    25045463  1.642058e-279  1.112537e-308  37.739453 -122.204015
# 1836509    12283845  1.334368e-284  1.112537e-308  37.793606 -122.276236
# 455853      2888010  3.521321e-291  1.112537e-308  37.804510 -122.272987
# 2301197    15618344  2.834528e-283  1.112537e-308  37.872170 -122.271150
#
#                          date         tract    home_tract
# 4028036  2014-04-19T19:26:50Z  6.001409e+09  6.001401e+09
# 3632268  2014-02-19T20:12:24Z  6.001409e+09  6.001409e+09
# 1836509  2013-07-25T01:56:25Z  6.001983e+09  6.075062e+09
# 455853   2012-10-26T02:09:21Z  6.001403e+09  6.075010e+09
# 2301197  2013-09-16T22:17:42Z  6.001422e+09  6.001422e+09

# %%
alameda_sample.to_csv("alameda_sample.csv")

# %%
alameda_sample_2 = alameda_sample.sample(int(.85*len(alameda_sample)))

# %%
len(alameda_sample_2)
# Out:
# 743172

# %%
alameda_sample_2.to_csv("alameda_sample.csv")

# %%
alameda_sample = pd.read_csv("alameda_sample.csv")

# %%
alameda_sample.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1             id           u_id        lat  \
# 0     6687538      45549635  2.638238e-270  1.112537e-308  37.704135
# 1     1657499      10992369  3.016355e-285  1.112537e-308  37.885946
# 2     6405793      43710377  3.626058e-271  1.112537e-308  37.668113
# 3     2267007      15376242  3.672158e-283  1.112537e-308  37.665651
# 4      554362       3493962  8.446129e-291  1.112537e-308  37.634858
#
#           lon                  date         tract    home_tract
# 0 -122.088003  2015-03-06T06:23:10Z  6.001431e+09  6.001431e+09
# 1 -122.309281  2013-06-27T20:43:25Z  6.001420e+09  6.013340e+09
# 2 -121.875291  2015-01-29T16:58:49Z  6.001451e+09  6.001451e+09
# 3 -122.079126  2013-09-21T18:23:26Z  6.001436e+09  6.001436e+09
# 4 -122.056420  2012-11-10T05:41:18Z  6.001435e+09  6.001438e+09

# %%
len(alameda_sample)
# Out:
# 743172

# %%
alameda_sample[alameda_sample.isnull().any(axis=1)]
# Out:
#         Unnamed: 0  Unnamed: 0.1             id           u_id        lat  \
# 1585        203115       1275268  5.178454e-292  1.112537e-308  37.822981
# 17838      6243352      42677078  2.749413e-271  1.112537e-308  37.838668
# 28064      4451672      30392793  1.459964e-277  1.112537e-308  37.841809
# 32745      5930127      40652690  1.904475e-272  1.112537e-308  37.809338
# 56028      3134045      21516927  4.323043e-280  1.112537e-308  37.865808
# 64843      4540043      30960839  1.471807e-277  1.112537e-308  37.651870
# 75172      2466461      16780499  2.343310e-282  1.112537e-308  37.741463
# 85882      2465907      16775782  2.492858e-282  1.112537e-308  37.742672
# 106298      459127       2909260  4.973701e-291  1.112537e-308  37.844806
# 127289      356399       2254756  2.578300e-291  1.112537e-308  37.794635
# 137752     3218027      22102230  2.018798e-280  1.112537e-308  37.803545
# 140115      106610        685009  1.265215e-292  1.112537e-308  37.828965
# ...

# %%
alameda_sample = alameda_sample.dropna(axis=0, how='any')

# %%
len(alameda_sample)
# Out:
# 743091

# %%
alameda_sample[alameda_sample.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, id, u_id, lat, lon, date, tract, home_tract]
# Index: []

# %%
len(alameda_sample)
# Out:
# 743066
